# %%
import pandas
import pandera

# %%
df = pandas.read_excel('dataframe_fo.xlsx', sheet_name="fo-op")
df.head(10)
# Out:
#    level_id  unit_id  distance_to_soti  distance_to_distribution_board  \
# 0         1      101                 1                              34
# 1         1      112                 1                              34
# 2         1      102                 1                              29
# 3         1      111                 1                              29
# 4         1      106                 1                              27
# 5         1      107                 1                              27
# 6         1      108                 1                              20
# 7         1      110                 1                              20
# 8         1      105                 1                              19
# 9         1      103                 1                              18
#
#    connector_id  number_of_cables cables_setup  total_cable_attenuation  \
# 0             1                 2      2:1 1:1                   0.0140
# ...

# %%
for column in df.columns:   
    print(f"{column}:" , df[column].dtype)
# Out:
# level_id: int64
# unit_id: int64
# distance_to_soti: int64
# distance_to_distribution_board: int64
# connector_id: int64
# number_of_cables: int64
# cables_setup: object
# total_cable_attenuation: float64
# total_unit_attenuation: float64

# %%
df.columns
# Out:
# Index(['level_id', 'unit_id', 'distance_to_soti',
#        'distance_to_distribution_board', 'connector_id', 'number_of_cables',
#        'cables_setup', 'total_cable_attenuation', 'total_unit_attenuation'],
#       dtype='object')

# %%
df2 = df[["level_id", 'unit_id']]
df2.head()
# Out:
#    level_id  unit_id
# 0         1      101
# 1         1      112
# 2         1      102
# 3         1      111
# 4         1      106

# %%
df3 = pandas.DataFrame({})

# %%
schema = pandera.DataFrameSchema({
    "level_id": pandera.Column(int, pandera.Check(lambda x: x >= 0), nullable=False, required=True),
    "unit_id": pandera.Column(str, nullable=False, required=True, coerce=True), 
    "distance_to_soti": pandera.Column(int, pandera.Check(lambda x: x >= 0), nullable=False, required=True), 
    "distance_to_distribution_board": pandera.Column(int, pandera.Check(lambda x: x >= 0), nullable=False, required=True), 
    "connector_id": pandera.Column(int, pandera.Check(lambda x: x >= 0), nullable=False, required=False),  
    "number_of_cables": pandera.Column(int, pandera.Check(lambda x: x >= 0), nullable=False, required=True), 
    "cables_setup": pandera.Column(str, nullable=False, required=True),  
    "total_cable_attenuation": pandera.Column(float, pandera.Check(lambda x: x >= 0), nullable=False, required=True), 
    "total_unit_attenuation": pandera.Column(float, pandera.Check(lambda x: x >= 0), nullable=False, required=True), 
    })

# if schema.validate(df, lazy=True)==True:
#     print('yes')

schema.validate(df, lazy=True).head()
# Out:
#    level_id unit_id  distance_to_soti  distance_to_distribution_board  \
# 0         1     101                 1                              34
# 1         1     112                 1                              34
# 2         1     102                 1                              29
# 3         1     111                 1                              29
# 4         1     106                 1                              27
#
#    connector_id  number_of_cables cables_setup  total_cable_attenuation  \
# 0             1                 2      2:1 1:1                   0.0140
# 1             1                 2      2:1 1:1                   0.0140
# 2             1                 2      2:1 1:1                   0.0120
# 3             1                 2      2:1 1:1                   0.0120
# 4             1                 2      2:1 1:1                   0.0112
#
#    total_unit_attenuation
# 0                  0.7140
# 1                  0.7140
# 2                  0.7120
# ...

# %%
for column in schema.validate(df, lazy=True).columns: 
    print(f"{column}:" , schema.validate(df, lazy=True)[column].dtype)
# Out:
# level_id: int64
# unit_id: object
# distance_to_soti: int64
# distance_to_distribution_board: int64
# connector_id: int64
# number_of_cables: int64
# cables_setup: object
# total_cable_attenuation: float64
# total_unit_attenuation: float64

# %%
df_wired_coaxial = pandas.read_excel("./dataframe_wired_coaxial.xlsx", sheet_name='catv-backbones-op-0')
df_wired_coaxial.head(10)
# Out:
#    level_id unit_id  distance_to_soti  distance_to_sots  \
# 0         1    102A              33.0              19.6
# 1         1    103A              33.0              19.6
# 2         1    104A              33.0              19.6
# 3         1    101A              33.0              19.6
# 4         2    204A              35.4              17.2
# 5         2    205A              35.4              17.2
# 6         2    201A              35.4              17.2
# 7         2    209A              35.4              17.2
# 8         2    203A              35.4              17.2
# 9         2    202A              35.4              17.2
#
#    distance_to_distribution_board backbone_cable_id lateral_net_cable_id  \
# 0                              25          T200PLUS             T100PLUS
# 1                              25          T200PLUS             T100PLUS
# 2                              17          T200PLUS             T100PLUS
# ...

# %%
df_wired_coaxial.columns
# Out:
# Index(['level_id', 'unit_id', 'distance_to_soti', 'distance_to_sots',
#        'distance_to_distribution_board', 'backbone_cable_id',
#        'lateral_net_cable_id', 'connector_id', 'derivator_id',
#        'backbone_index', 'derivator_index', 'splitter_attenuation',
#        'connector_attenuation', 'backbone_cable_attenuation_with_47mhz',
#        'backbone_cable_attenuation_with_1350mhz',
#        'lateral_net_cable_attenuation_with_47mhz',
#        'lateral_net_cable_attenuation_with_1350mhz', 'derivator_attenuation',
#        'derivator_step_attenuation',
#        'cumulative_level_derivator_step_attenuation',
#        'total_attenuation_with_47mhz', 'total_attenuation_with_1350mhz'],
#       dtype='object')

# %%
df_wired_coaxial['distance_to_sots'].dtype
# Out:
# dtype('float64')

# %%
for column in df_wired_coaxial.columns:   
    print(f"{column}:" , df_wired_coaxial[column].dtype)
# Out:
# level_id: int64
# unit_id: object
# distance_to_soti: float64
# distance_to_sots: float64
# distance_to_distribution_board: int64
# backbone_cable_id: object
# lateral_net_cable_id: object
# connector_id: int64
# derivator_id: int64
# backbone_index: int64
# derivator_index: int64
# splitter_attenuation: int64
# connector_attenuation: float64
# backbone_cable_attenuation_with_47mhz: float64
# backbone_cable_attenuation_with_1350mhz: float64
# lateral_net_cable_attenuation_with_47mhz: float64
# lateral_net_cable_attenuation_with_1350mhz: float64
# derivator_attenuation: float64
# derivator_step_attenuation: float64
# cumulative_level_derivator_step_attenuation: float64
# total_attenuation_with_47mhz: float64
# total_attenuation_with_1350mhz: float64

# %%
df_wired_coaxial_with_amplifier = pandas.read_excel("./dataframe_wired_coaxial_with_amplifier.xlsx", sheet_name='catv-amplifiers-op-2')
df_wired_coaxial_with_amplifier.head(10)
# Out:
#    level_id   unit_id  distance_to_soti  distance_to_sots  \
# 0         1  Local 21              15.0              41.2
# 1         1  Local 20              15.0              41.2
# 2         1  Local 19              15.0              41.2
# 3         1  Local 18              15.0              41.2
# 4         1  Local 17              15.0              41.2
# 5         1  Local 13              15.0              41.2
# 6         1  Local 16              15.0              41.2
# 7         1  Local 14              15.0              41.2
# 8         1  Local 15              15.0              41.2
# 9         2       208              17.4              38.8
#
#    distance_to_distribution_board backbone_cable_id lateral_net_cable_id  \
# 0                              31          T200PLUS             T100PLUS
# 1                              28          T200PLUS             T100PLUS
# 2                              25          T200PLUS             T100PLUS
# ...

# %%
df_wired_coaxial_with_amplifier.columns
# Out:
# Index(['level_id', 'unit_id', 'distance_to_soti', 'distance_to_sots',
#        'distance_to_distribution_board', 'backbone_cable_id',
#        'lateral_net_cable_id', 'connector_id', 'derivator_id',
#        'backbone_index', 'derivator_index', 'splitter_attenuation',
#        'connector_attenuation', 'backbone_cable_attenuation_with_47mhz',
#        'backbone_cable_attenuation_with_1350mhz',
#        'lateral_net_cable_attenuation_with_47mhz',
#        'lateral_net_cable_attenuation_with_1350mhz', 'derivator_attenuation',
#        'derivator_step_attenuation',
#        'cumulative_level_derivator_step_attenuation',
#        'total_attenuation_with_47mhz', 'total_attenuation_with_1350mhz',
#        'amplifier_id', 'amplifier_index', 'amplifier_power',
#        'total_attenuation_amplifiers_with_47mhz',
#        'total_attenuation_amplifiers_with_1350mhz'],
#       dtype='object')

# %%
for column in df_wired_coaxial_with_amplifier.columns:   
    print(f"{column}:" , df_wired_coaxial_with_amplifier[column].dtype)
# Out:
# level_id: int64
# unit_id: object
# distance_to_soti: float64
# distance_to_sots: float64
# distance_to_distribution_board: int64
# backbone_cable_id: object
# lateral_net_cable_id: object
# connector_id: int64
# derivator_id: int64
# backbone_index: int64
# derivator_index: int64
# splitter_attenuation: int64
# connector_attenuation: float64
# backbone_cable_attenuation_with_47mhz: float64
# backbone_cable_attenuation_with_1350mhz: float64
# lateral_net_cable_attenuation_with_47mhz: float64
# lateral_net_cable_attenuation_with_1350mhz: float64
# derivator_attenuation: float64
# derivator_step_attenuation: float64
# cumulative_level_derivator_step_attenuation: float64
# total_attenuation_with_47mhz: float64
# total_attenuation_with_1350mhz: float64
# amplifier_id: int64
# amplifier_index: int64
# amplifier_power: float64
# total_attenuation_amplifiers_with_47mhz: float64
# total_attenuation_amplifiers_with_1350mhz: float64

# %% [markdown]
# # Conditional to diference between with amplifier or without amplifier

# %%
def verify_dataframe(df_1: pandas.DataFrame, df_2: pandas.DataFrame) -> str:
    print("estas columnas no esta en df_2:")
    for column_1 in df_1.columns:
        if column_1 in df_2.columns:
            pass
        else:
            print(f"{column_1}", df_1[column_1].dtype)
    
    print("\nestas columnas no esta en df_1:")
    for column_2 in df_2.columns:
        if column_2 in df_1.columns:
            pass
        else:
            print(f"{column_2}", df_2[column_2].dtype)

# %%
verify_dataframe(df_1=df_wired_coaxial, df_2=df_wired_coaxial_with_amplifier)
# Out:
# estas columnas no esta en df_2:
#
# estas columnas no esta en df_1:
# amplifier_id int64
# amplifier_index int64
# amplifier_power float64
# total_attenuation_amplifiers_with_47mhz float64
# total_attenuation_amplifiers_with_1350mhz float64

# %%
schema = pandera.DataFrameSchema({
    'level_id': pandera.Column(int, pandera.Check(lambda x: x >= 0), nullable=False, required=True),
    'unit_id': pandera.Column(str, nullable=False, required=True),
    'distance_to_soti': pandera.Column(float, pandera.Check(lambda x: x >= 0), nullable=False, required=True),
    'distance_to_sots': pandera.Column(float, pandera.Check(lambda x: x >= 0), nullable=False, required=True),
    'distance_to_distribution_board': pandera.Column(int, pandera.Check(lambda x: x >= 0), nullable=False, required=True),
    'backbone_cable_id': pandera.Column(str, nullable=False, required=True),
    'lateral_net_cable_id': pandera.Column(str, nullable=False, required=True),
    'connector_id': pandera.Column(int, pandera.Check(lambda x: x >= 0), nullable=False, required=True),
    'derivator_id': pandera.Column(int, pandera.Check(lambda x: x >= 0), nullable=False, required=True),
    'backbone_index': pandera.Column(int, pandera.Check(lambda x: x >= 0), nullable=False, required=True),
    'derivator_index': pandera.Column(int, pandera.Check(lambda x: x >= 0), nullable=False, required=True),
    'splitter_attenuation': pandera.Column(int, pandera.Check(lambda x: x >= 0), nullable=False, required=True),
    'connector_attenuation': pandera.Column(float, pandera.Check(lambda x: x >= 0), nullable=False, required=True),
    'backbone_cable_attenuation_with_47mhz': pandera.Column(float, pandera.Check(lambda x: x >= 0), nullable=False, required=True),
    'backbone_cable_attenuation_with_1350mhz': pandera.Column(float, pandera.Check(lambda x: x >= 0), nullable=False, required=True),
    'lateral_net_cable_attenuation_with_47mhz': pandera.Column(float, pandera.Check(lambda x: x >= 0), nullable=False, required=True),
    'lateral_net_cable_attenuation_with_1350mhz': pandera.Column(float, pandera.Check(lambda x: x >= 0), nullable=False, required=True),
    'derivator_attenuation': pandera.Column(float, pandera.Check(lambda x: x >= 0), nullable=False, required=True),
    'derivator_step_attenuation': pandera.Column(float, pandera.Check(lambda x: x >= 0), nullable=False, required=True),
    'cumulative_level_derivator_step_attenuation': pandera.Column(float, pandera.Check(lambda x: x >= 0), nullable=False, required=True),
    'total_attenuation_with_47mhz': pandera.Column(float, pandera.Check(lambda x: x >= 0), nullable=False, required=True),
    'total_attenuation_with_1350mhz': pandera.Column(float, pandera.Check(lambda x: x >= 0), nullable=False, required=True),
    'amplifier_id': pandera.Column(int, pandera.Check(lambda x: x >= 0), nullable=False, required=True),
    'amplifier_index': pandera.Column(int, pandera.Check(lambda x: x >= 0), nullable=False, required=True),
    'amplifier_power': pandera.Column(float, pandera.Check(lambda x: x >= 0), nullable=False, required=True),
    'total_attenuation_amplifiers_with_47mhz': pandera.Column(float, pandera.Check(lambda x: x >= 0), nullable=False, required=True),
    'total_attenuation_amplifiers_with_1350mhz': pandera.Column(float, pandera.Check(lambda x: x >= 0), nullable=False, required=True)
    })

# %%
if schema.validate(df_wired_coaxial_with_amplifier, lazy=True).columns.all() == df_wired_coaxial_with_amplifier.columns.all():
    print('yeah')
# Out:
# yeah

# %%
type(schema.validate(df_wired_coaxial_with_amplifier, lazy=True))
# Out:
# pandas.core.frame.DataFrame

# %%
data_schema = schema.validate(df_wired_coaxial, lazy=True)
# Out:
# ---------------------------------------------------------------------------
# SchemaErrors                              Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17008/2570139589.py in <module>
# ----> 1 data_schema = schema.validate(df_wired_coaxial, lazy=True)
#
# c:\Users\HP\Documents\GitHub\1.__Dustin.py\.venv\lib\site-packages\pandera\schemas.py in validate(self, check_obj, head, tail, sample, random_state, lazy, inplace)
#     652
#     653         if lazy and error_handler.collected_errors:
# --> 654             raise errors.SchemaErrors(
#     655                 error_handler.collected_errors, check_obj
#     656             )
#
# SchemaErrors: A total of 5 schema errors were found.
#
# Error Counts
# ------------
# - column_not_in_dataframe: 5
#
# Schema Error Summary
# --------------------
# ...

# %% [markdown]
# # Wireless Coaxial

# %%
df_wireless_coaxial = pandas.read_excel('./dataframe_wireless_coaxial.xlsx', sheet_name='smatv-backbones-op-1')
df_wireless_coaxial.head(10)
# Out:
#    level_id unit_id  distance_to_soti  distance_to_sots  \
# 0         5    504A              42.6              10.0
# 1         5    505A              42.6              10.0
# 2         5    501A              42.6              10.0
# 3         5    509A              42.6              10.0
# 4         5    503A              42.6              10.0
# 5         5    502A              42.6              10.0
# 6         5    506A              42.6              10.0
# 7         5    507A              42.6              10.0
# 8         5    508A              42.6              10.0
# 9         4    404A              40.2              12.4
#
#    distance_to_distribution_board  distance_to_main_enclosure  \
# 0                              25                           9
# 1                              24                           9
# 2                              23                           9
# 3                              16                           9
# ...

# %%
for column in df_wireless_coaxial.columns:   
    print(f"{column}:" , df_wireless_coaxial[column].dtype)
# Out:
# level_id: int64
# unit_id: object
# distance_to_soti: float64
# distance_to_sots: float64
# distance_to_distribution_board: int64
# distance_to_main_enclosure: int64
# backbone_cable_id: object
# lateral_net_cable_id: object
# connector_id: int64
# derivator_id: int64
# backbone_index: int64
# derivator_index: int64
# splitter_matv_attenuation: int64
# splitter_fi_attenuation: int64
# connector_attenuation: float64
# backbone_cable_attenuation_with_800mhz: float64
# backbone_cable_attenuation_with_2300mhz: float64
# lateral_net_cable_attenuation_with_800mhz: float64
# lateral_net_cable_attenuation_with_2300mhz: float64
# internal_net_cable_attenuation_with_800mhz: float64
# internal_net_cable_attenuation_with_2300mhz: float64
# derivator_matv_attenuation: int64
# derivator_fi_attenuation: int64
# derivator_matv_step_attenuation: float64
# derivator_fi_step_attenuation: float64
# cumulative_level_derivator_matv_step_attenuation: float64
# ...

# %%
df_wireless_coaxial_with_amplifier = pandas.read_excel('./dataframe_wireless_coaxial_with_amplifier.xlsx', sheet_name='smatv-amplifiers-op-0')
df_wireless_coaxial_with_amplifier.head(10)
# Out:
#    level_id unit_id  distance_to_soti  distance_to_sots  \
# 0        14    1402              46.2              10.0
# 1        14    1403              46.2              10.0
# 2        14    1404              46.2              10.0
# 3        14    1401              46.2              10.0
# 4        14    1405              46.2              10.0
# 5        13    1308              43.8              12.4
# 6        13    1309              43.8              12.4
# 7        13    1302              43.8              12.4
# 8        13    1303              43.8              12.4
# 9        13    1307              43.8              12.4
#
#    distance_to_distribution_board  distance_to_main_enclosure  \
# 0                              27                           9
# 1                              27                           9
# 2                              11                           9
# 3                              10                           9
# ...

# %%
for column in df_wireless_coaxial_with_amplifier.columns:   
    print(f"{column}:" , df_wireless_coaxial_with_amplifier[column].dtype)
# Out:
# level_id: int64
# unit_id: object
# distance_to_soti: float64
# distance_to_sots: float64
# distance_to_distribution_board: int64
# distance_to_main_enclosure: int64
# backbone_cable_id: object
# lateral_net_cable_id: object
# connector_id: int64
# derivator_id: int64
# backbone_index: int64
# derivator_index: int64
# splitter_matv_attenuation: int64
# splitter_fi_attenuation: int64
# connector_attenuation: float64
# backbone_cable_attenuation_with_800mhz: float64
# backbone_cable_attenuation_with_2300mhz: float64
# lateral_net_cable_attenuation_with_800mhz: float64
# lateral_net_cable_attenuation_with_2300mhz: float64
# internal_net_cable_attenuation_with_800mhz: float64
# internal_net_cable_attenuation_with_2300mhz: float64
# derivator_matv_attenuation: int64
# derivator_fi_attenuation: int64
# derivator_matv_step_attenuation: float64
# derivator_fi_step_attenuation: float64
# cumulative_level_derivator_matv_step_attenuation: float64
# ...

# %%
verify_dataframe(df_1=df_wireless_coaxial, df_2=df_wireless_coaxial_with_amplifier)
# Out:
# estas columnas no esta en df_2:
#
# estas columnas no esta en df_1:
# amplifier_id int64
# amplifier_index int64
# amplificador_fi float64
# pw_with_ampli_fi float64
# amplificador_matv float64
# pw_with_ampli_matv float64

# %%
schema = pandera.DataFrameSchema({
    'level_id': pandera.Column(int, pandera.Check(lambda x: x >= 0), nullable=False, required=True),
    'unit_id': pandera.Column(str, nullable=False, required=True),
    'distance_to_soti': pandera.Column(float, pandera.Check(lambda x: x >= 0), nullable=False, required=True),
    'distance_to_sots': pandera.Column(float, pandera.Check(lambda x: x >= 0), nullable=False, required=True),
    'distance_to_distribution_board': pandera.Column(int, pandera.Check(lambda x: x >= 0), nullable=False, required=True),
    'distance_to_main_enclosure': pandera.Column(int, pandera.Check(lambda x: x >= 0), nullable=False, required=True),
    'backbone_cable_id': pandera.Column(str, nullable=False, required=True),
    'lateral_net_cable_id': pandera.Column(str, nullable=False, required=True),
    'connector_id': pandera.Column(int, pandera.Check(lambda x: x >= 0), nullable=False, required=True),
    'derivator_id': pandera.Column(int, pandera.Check(lambda x: x >= 0), nullable=False, required=True),
    'backbone_index': pandera.Column(int, pandera.Check(lambda x: x >= 0), nullable=False, required=True),
    'derivator_index': pandera.Column(int, pandera.Check(lambda x: x >= 0), nullable=False, required=True),
    'splitter_matv_attenuation': pandera.Column(int, pandera.Check(lambda x: x >= 0), nullable=False, required=True),
    'splitter_fi_attenuation': pandera.Column(int, pandera.Check(lambda x: x >= 0), nullable=False, required=True),
    'connector_attenuation': pandera.Column(float, pandera.Check(lambda x: x >= 0), nullable=False, required=True),
    'backbone_cable_attenuation_with_800mhz': pandera.Column(float, pandera.Check(lambda x: x >= 0), nullable=False, required=True),
    'backbone_cable_attenuation_with_2300mhz': pandera.Column(float, pandera.Check(lambda x: x >= 0), nullable=False, required=True),
    'lateral_net_cable_attenuation_with_800mhz': pandera.Column(float, pandera.Check(lambda x: x >= 0), nullable=False, required=True),
    'lateral_net_cable_attenuation_with_2300mhz': pandera.Column(float, pandera.Check(lambda x: x >= 0), nullable=False, required=True),
    'internal_net_cable_attenuation_with_800mhz': pandera.Column(float, pandera.Check(lambda x: x >= 0), nullable=False, required=True),
    'internal_net_cable_attenuation_with_2300mhz': pandera.Column(float, pandera.Check(lambda x: x >= 0), nullable=False, required=True),
    'derivator_matv_attenuation': pandera.Column(int, pandera.Check(lambda x: x >= 0), nullable=False, required=True),
    'derivator_fi_attenuation': pandera.Column(int, pandera.Check(lambda x: x >= 0), nullable=False, required=True),
    'derivator_matv_step_attenuation': pandera.Column(float, pandera.Check(lambda x: x >= 0), nullable=False, required=True),
    'derivator_fi_step_attenuation': pandera.Column(float, pandera.Check(lambda x: x >= 0), nullable=False, required=True),
    'cumulative_level_derivator_matv_step_attenuation': pandera.Column(float, pandera.Check(lambda x: x >= 0), nullable=False, required=True),
    'cumulative_level_derivator_fi_step_attenuation': pandera.Column(float, pandera.Check(lambda x: x >= 0), nullable=False, required=True),
    'total_matv_attenuation': pandera.Column(float, pandera.Check(lambda x: x >= 0), nullable=False, required=True),
    'total_fi_attenuation': pandera.Column(float, pandera.Check(lambda x: x >= 0), nullable=False, required=True),
    'total_matv_power': pandera.Column(float, pandera.Check(lambda x: x >= 0), nullable=False, required=True),
    'total_fi_power': pandera.Column(float, nullable=False, required=True),
    'amplifier_id': pandera.Column(int, pandera.Check(lambda x: x >= 0), nullable=False, required=True),
    'amplifier_index': pandera.Column(int, pandera.Check(lambda x: x >= 0), nullable=False, required=True),
    'amplificador_fi': pandera.Column(float, pandera.Check(lambda x: x >= 0), nullable=False, required=True),
    'pw_with_ampli_fi': pandera.Column(float, pandera.Check(lambda x: x >= 0), nullable=False, required=True),
    'amplificador_matv': pandera.Column(float, pandera.Check(lambda x: x >= 0), nullable=False, required=True),
    'pw_with_ampli_matv': pandera.Column(float, pandera.Check(lambda x: x >= 0), nullable=False, required=True)
    })

# %%
schema.validate(df_wireless_coaxial_with_amplifier, lazy=True)
# Out:
#      level_id   unit_id  distance_to_soti  distance_to_sots  \
# 0          14      1402              46.2              10.0
# 1          14      1403              46.2              10.0
# 2          14      1404              46.2              10.0
# 3          14      1401              46.2              10.0
# 4          14      1405              46.2              10.0
# ..        ...       ...               ...               ...
# 141         1  Local 17              15.0              41.2
# 142         1  Local 13              15.0              41.2
# 143         1  Local 16              15.0              41.2
# 144         1  Local 14              15.0              41.2
# 145         1  Local 15              15.0              41.2
#
#      distance_to_distribution_board  distance_to_main_enclosure  \
# 0                                27                           9
# 1                                27                           9
# ...

# %%
schema.validate(df_wireless_coaxial, lazy=True)
# Out:
# ---------------------------------------------------------------------------
# SchemaErrors                              Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17008/865260965.py in <module>
# ----> 1 schema.validate(df_wireless_coaxial, lazy=True)
#
# c:\Users\HP\Documents\GitHub\1.__Dustin.py\.venv\lib\site-packages\pandera\schemas.py in validate(self, check_obj, head, tail, sample, random_state, lazy, inplace)
#     652
#     653         if lazy and error_handler.collected_errors:
# --> 654             raise errors.SchemaErrors(
#     655                 error_handler.collected_errors, check_obj
#     656             )
#
# SchemaErrors: A total of 6 schema errors were found.
#
# Error Counts
# ------------
# - column_not_in_dataframe: 6
#
# Schema Error Summary
# --------------------
#                                                                                                                                         failure_cases  n_failure_cases
# ...
