# %%
import pandas

# %%
df = pandas.read_csv(r'C:\Users\HP\Documents\GitHub\1.__Dustin.py\2. Pandas\dataframeutf8.csv')

# %%
df
# Out:
#    Nombre y apellido  Edad       País Automovil
# 0               Juan    66       Peru        Si
# 1              Pedro    35  Argentina        Si
# 2              Maria    41     Mexico        No
# 3              Laura    35   Honduras        No
# 4               Juan    41       Peru        No
# 5              Pedro    28       Peru        Si
# 6              Maria    66  Argentina        Si
# 7              Laura    35     Mexico        Si
# 8               Juan    41   Honduras        Si
# 9              Pedro    28       Peru        No
# 10             Maria    28       Peru        No
# 11             Laura    66  Argentina        No
# 12              Juan    35     Mexico        Si
# 13             Pedro    41   Honduras        Si
# 14             Maria    28       Peru        No
# 15             Laura    66  Argentina        No
# 16              Juan    35     Mexico        No
# 17             Pedro    41   Honduras        Si
# 18             Maria    35       Peru        Si
# ...

# %%
df.País.value_counts(ascending=True, dropna=False)
# Out:
# Honduras      6
# Argentina     7
# Mexico        7
# Peru         11
# Name: País, dtype: int64

# %%
df.País.sort_values()
# Out:
# 15    Argentina
# 1     Argentina
# 28    Argentina
# 25    Argentina
# 20    Argentina
# 6     Argentina
# 11    Argentina
# 22     Honduras
# 17     Honduras
# 13     Honduras
# 30     Honduras
# 8      Honduras
# 3      Honduras
# 12       Mexico
# 2        Mexico
# 29       Mexico
# 16       Mexico
# 7        Mexico
# 26       Mexico
# 21       Mexico
# 9          Peru
# 27         Peru
# 24         Peru
# 5          Peru
# 4          Peru
# 10         Peru
# 19         Peru
# 18         Peru
# 14         Peru
# 23         Peru
# 0          Peru
# Name: País, dtype: object

# %%
df.sort_values(by=['Edad'])
# Out:
#    Nombre y apellido  Edad       País Automovil
# 30             Laura    28   Honduras        No
# 20              Juan    28  Argentina        No
# 14             Maria    28       Peru        No
# 10             Maria    28       Peru        No
# 9              Pedro    28       Peru        No
# 24             Pedro    28       Peru        No
# 5              Pedro    28       Peru        Si
# 28             Pedro    35  Argentina        No
# 22             Maria    35   Honduras        Si
# 26             Laura    35     Mexico        Si
# 1              Pedro    35  Argentina        Si
# 18             Maria    35       Peru        Si
# 16              Juan    35     Mexico        No
# 12              Juan    35     Mexico        Si
# 3              Laura    35   Honduras        No
# 7              Laura    35     Mexico        Si
# 2              Maria    41     Mexico        No
# 23             Laura    41       Peru        No
# 27              Juan    41       Peru        No
# ...

# %%
df[df.Edad==28]
# Out:
#    Nombre y apellido  Edad       País Automovil
# 5              Pedro    28       Peru        Si
# 9              Pedro    28       Peru        No
# 10             Maria    28       Peru        No
# 14             Maria    28       Peru        No
# 20              Juan    28  Argentina        No
# 24             Pedro    28       Peru        No
# 30             Laura    28   Honduras        No

# %%
df[(df['Edad']==28) & (df['País']=='Peru')]
# Out:
#    Nombre y apellido  Edad  País Automovil
# 5              Pedro    28  Peru        Si
# 9              Pedro    28  Peru        No
# 10             Maria    28  Peru        No
# 14             Maria    28  Peru        No
# 24             Pedro    28  Peru        No

# %%
df[(df['Edad']==28) | (df['País']=='Peru')]
# Out:
#          País Nombre y apellido  Edad Automovil
# 0        Peru              Juan    66        Si
# 1        Peru             Laura    41        No
# 2        Peru             Maria    28        No
# 3        Peru             Maria    35        Si
# 4        Peru             Laura    41        No
# 5        Peru             Maria    28        No
# 6        Peru              Juan    41        No
# 7        Peru             Pedro    28        Si
# 8        Peru             Pedro    28        No
# 9        Peru              Juan    41        No
# 10       Peru             Pedro    28        No
# 20   Honduras             Laura    28        No
# 27  Argentina              Juan    28        No

# %%
df[((df['Edad']==28) | (df['País']=='Peru')) & (df['Automovil']=='No')]
# Out:
#          País Nombre y apellido  Edad Automovil
# 1        Peru             Laura    41        No
# 2        Peru             Maria    28        No
# 4        Peru             Laura    41        No
# 5        Peru             Maria    28        No
# 6        Peru              Juan    41        No
# 8        Peru             Pedro    28        No
# 9        Peru              Juan    41        No
# 10       Peru             Pedro    28        No
# 20   Honduras             Laura    28        No
# 27  Argentina              Juan    28        No

# %%
#FILTRADO POR STRING
df[df.País.str.contains('Arg')]
# Out:
#    Nombre y apellido  Edad       País Automovil
# 1              Pedro    35  Argentina        Si
# 6              Maria    66  Argentina        Si
# 11             Laura    66  Argentina        No
# 15             Laura    66  Argentina        No
# 20              Juan    28  Argentina        No
# 25             Maria    66  Argentina        Si
# 28             Pedro    35  Argentina        No

# %%
df.set_index('País', inplace=True)
df.head()
# Out:
#           Nombre y apellido  Edad Automovil
# País
# Peru                   Juan    66        Si
# Argentina             Pedro    35        Si
# Mexico                Maria    41        No
# Honduras              Laura    35        No
# Peru                   Juan    41        No

# %%
df.reset_index(inplace=True)
df.head()
# Out:
#         País Nombre y apellido  Edad Automovil
# 0       Peru              Juan    66        Si
# 1  Argentina             Pedro    35        Si
# 2     Mexico             Maria    41        No
# 3   Honduras             Laura    35        No
# 4       Peru              Juan    41        No

# %%
df.set_index('País', inplace=True)
df.sort_index(inplace=True)
df
# Out:
#           Nombre y apellido  Edad Automovil
# País
# Argentina             Laura    66        No
# Argentina             Pedro    35        Si
# Argentina             Pedro    35        No
# Argentina             Maria    66        Si
# Argentina              Juan    28        No
# Argentina             Maria    66        Si
# Argentina             Laura    66        No
# Honduras              Maria    35        Si
# Honduras              Pedro    41        Si
# Honduras              Pedro    41        Si
# Honduras              Laura    28        No
# Honduras               Juan    41        Si
# Honduras              Laura    35        No
# Mexico                 Juan    35        Si
# Mexico                Maria    41        No
# Mexico                Maria    41        Si
# Mexico                 Juan    35        No
# Mexico                Laura    35        Si
# Mexico                Laura    35        Si
# Mexico                Pedro    66        Si
# ...

# %%
df.sort_index(inplace=True, ascending=False)
df
# Out:
#           Nombre y apellido  Edad Automovil
# País
# Peru                   Juan    66        Si
# Peru                  Laura    41        No
# Peru                  Maria    28        No
# Peru                  Maria    35        Si
# Peru                  Laura    41        No
# Peru                  Maria    28        No
# Peru                   Juan    41        No
# Peru                  Pedro    28        Si
# Peru                  Pedro    28        No
# Peru                   Juan    41        No
# Peru                  Pedro    28        No
# Mexico                 Juan    35        No
# Mexico                Pedro    66        Si
# Mexico                Laura    35        Si
# Mexico                Laura    35        Si
# Mexico                Maria    41        Si
# Mexico                Maria    41        No
# Mexico                 Juan    35        Si
# Honduras              Laura    35        No
# Honduras               Juan    41        Si
# ...

# %%
#BUSQUEDA SEGUN LAS FILAS
df.loc['Argentina']
# Out:
#           Nombre y apellido  Edad Automovil
# País
# Argentina             Pedro    35        Si
# Argentina             Laura    66        No
# Argentina             Maria    66        Si
# Argentina              Juan    28        No
# Argentina             Maria    66        Si
# Argentina             Pedro    35        No
# Argentina             Laura    66        No

# %%
df.reset_index(inplace=True)
df.loc[df['País']=='Peru']
# Out:
#     País Nombre y apellido  Edad Automovil
# 0   Peru              Juan    66        Si
# 1   Peru             Laura    41        No
# 2   Peru             Maria    28        No
# 3   Peru             Maria    35        Si
# 4   Peru             Laura    41        No
# 5   Peru             Maria    28        No
# 6   Peru              Juan    41        No
# 7   Peru             Pedro    28        Si
# 8   Peru             Pedro    28        No
# 9   Peru              Juan    41        No
# 10  Peru             Pedro    28        No

# %%
df.iloc[[4]]
# Out:
#    País Nombre y apellido  Edad Automovil
# 4  Peru             Laura    41        No

# %%
df.iloc[2:5]
# Out:
#    País Nombre y apellido  Edad Automovil
# 2  Peru             Maria    28        No
# 3  Peru             Maria    35        Si
# 4  Peru             Laura    41        No

# %%
list(df.groupby('País'))
# Out:
# [('Argentina',
#            País Nombre y apellido  Edad Automovil
#   24  Argentina             Pedro    35        Si
#   25  Argentina             Laura    66        No
#   26  Argentina             Maria    66        Si
#   27  Argentina              Juan    28        No
#   28  Argentina             Maria    66        Si
#   29  Argentina             Pedro    35        No
#   30  Argentina             Laura    66        No),
#  ('Honduras',
#           País Nombre y apellido  Edad Automovil
#   18  Honduras             Laura    35        No
#   19  Honduras              Juan    41        Si
#   20  Honduras             Laura    28        No
#   21  Honduras             Pedro    41        Si
#   22  Honduras             Pedro    41        Si
#   23  Honduras             Maria    35        Si),
#  ('Mexico',
#         País Nombre y apellido  Edad Automovil
#   11  Mexico              Juan    35        No
#   12  Mexico             Pedro    66        Si
# ...

# %%
for group_key, group_value in df.groupby('Automovil'):
    print(group_key)
    print(group_value)
# Out:
# No
#          País Nombre y apellido  Edad Automovil
# 1        Peru             Laura    41        No
# 2        Peru             Maria    28        No
# 4        Peru             Laura    41        No
# 5        Peru             Maria    28        No
# 6        Peru              Juan    41        No
# 8        Peru             Pedro    28        No
# 9        Peru              Juan    41        No
# 10       Peru             Pedro    28        No
# 11     Mexico              Juan    35        No
# 16     Mexico             Maria    41        No
# 18   Honduras             Laura    35        No
# 20   Honduras             Laura    28        No
# 25  Argentina             Laura    66        No
# 27  Argentina              Juan    28        No
# 29  Argentina             Pedro    35        No
# 30  Argentina             Laura    66        No
# Si
#          País Nombre y apellido  Edad Automovil
# 0        Peru              Juan    66        Si
# ...

# %%
df.groupby(['País', 'Automovil', 'Edad']).agg('min', 'max', 'mean')
# Out:
# Empty DataFrame
# Columns: []
# Index: [(Argentina, No, 28), (Argentina, No, 35), (Argentina, No, 66), (Argentina, Si, 35), (Argentina, Si, 66), (Honduras, No, 28), (Honduras, No, 35), (Honduras, Si, 35), (Honduras, Si, 41), (Mexico, No, 35), (Mexico, No, 41), (Mexico, Si, 35), (Mexico, Si, 41), (Mexico, Si, 66), (Peru, No, 28), (Peru, No, 41), (Peru, Si, 28), (Peru, Si, 35), (Peru, Si, 66)]

# %%
df.groupby(['País', 'Edad']).agg({'Edad': ['min', 'max', 'count', 'mean']})
# Out:
#                Edad
#                 min max count  mean
# País      Edad
# Argentina 28     28  28     1  28.0
#           35     35  35     2  35.0
#           66     66  66     4  66.0
# Honduras  28     28  28     1  28.0
#           35     35  35     2  35.0
#           41     41  41     3  41.0
# Mexico    35     35  35     4  35.0
#           41     41  41     2  41.0
#           66     66  66     1  66.0
# Peru      28     28  28     5  28.0
#           35     35  35     1  35.0
#           41     41  41     4  41.0
#           66     66  66     1  66.0

# %%
filtrado = df[((df['Edad']==28) | (df['País']=='Peru')) & (df['Automovil']=='No')]
agrupamos = filtrado.groupby(['País', 'Automovil']).size()
agrupamos
# Out:
# País       Automovil
# Argentina  No           1
# Honduras   No           1
# Peru       No           8
# dtype: int64

# %%
amontonar = agrupamos.unstack('Automovil')
amontonar
# Out:
# Automovil  No
# País
# Argentina   1
# Honduras    1
# Peru        8

# %% [markdown]
# # Graficas con matplotlib

# %%
import pandas
# import matplotlib.pyplot as plt
# %matplotlib inline

# %%
excel = pandas.read_csv('./finanzas.csv')
excel
# Out:
#          Fecha          Vendedor Región           Artículo    Categoría  \
# 0     1/1/2016      Steve Ashton  Norte   Medias Femeninas   Vestimenta
# 1     1/1/2016  Trevor Snodgrass  Oeste          Chocolate  Comestibles
# 2     1/1/2016        Sarah Bond    Sur             Gorras   Vestimenta
# 3     1/1/2016   Desmond Delaney    Sur  Sánguche de Queso  Comestibles
# 4     1/1/2016   Desmond Delaney   Este          Chocolate  Comestibles
# ..         ...               ...    ...                ...          ...
# 455  31/1/2016        Sarah Bond    Sur            Bufanda   Vestimenta
# 456  31/1/2016        Dustin Gee   Este          Sandalias   Vestimenta
# 457  31/1/2016        Dustin Gee   Este  Sánguche de Queso  Comestibles
# 458  31/1/2016        Dustin Gee  Norte         Escobillón        Hogar
# 459  31/1/2016  Trevor Snodgrass    Sur          Pepinillo  Comestibles
#
#      Unidades  Ganancia
# 0           6        18
# 1           8         4
# 2           3         6
# ...

# %%
vol = excel[excel.Categoría == 'Comestibles']
vol.head()
# Out:
#       Fecha          Vendedor Región           Artículo    Categoría  \
# 1  1/1/2016  Trevor Snodgrass  Oeste          Chocolate  Comestibles
# 3  1/1/2016   Desmond Delaney    Sur  Sánguche de Queso  Comestibles
# 4  1/1/2016   Desmond Delaney   Este          Chocolate  Comestibles
# 5  1/1/2016  Trevor Snodgrass   Este            Cerveza  Comestibles
# 6  1/1/2016    Boris Stanford  Norte          Pepinillo  Comestibles
#
#    Unidades  Ganancia
# 1         8         4
# 3         9        14
# 4        14         7
# 5        15         6
# 6        14         4

# %%
vol.Artículo.value_counts()
# Out:
# Pan                  26
# Chocolate            25
# Sánguche de Queso    25
# Pepinillo            24
# Soda                 19
# Cerveza              17
# Caramelos            17
# Name: Artículo, dtype: int64

# %%
vol.Artículo.value_counts().plot()
# Out:
# <AxesSubplot:>

# %%
vol.Artículo.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
vol.Artículo.value_counts().plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
vol.Artículo.value_counts().plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='Artículo'>

# %%
excel.plot(kind = "scatter", x='Unidades', y='Ganancia')
# Out:
# <AxesSubplot:xlabel='Unidades', ylabel='Ganancia'>

# %%
vol.Artículo.value_counts().plot(color='green', figsize=(10,5))
# Out:
# <AxesSubplot:>
